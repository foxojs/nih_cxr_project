# %%
import pandas as pd

# %%
filename = "/rds/general/user/ojf24/home/ml_project/vit_pretrained_fine_tune/tensorboard_logs/nih_cxr_pretrained_vit/version_7/metrics.csv"
training_metrics = pd.read_csv(filename)

# %%
training_metrics
# Out:
#        epoch    step  train_loss  val_multi_label_f1
# 0          0      49    0.262525                 NaN
# 1          0      99    0.179730                 NaN
# 2          0     149    0.159236                 NaN
# 3          0     199    0.092729                 NaN
# 4          0     249    0.149608                 NaN
# ...      ...     ...         ...                 ...
# 13143     75  653449    0.003345                 NaN
# 13144     75  653499    0.000807                 NaN
# 13145     75  653549    0.023626                 NaN
# 13146     75  653599    0.008573                 NaN
# 13147     75  653649    0.000793                 NaN
#
# [13148 rows x 4 columns]

# %%
import seaborn as sns

sns.lineplot(x = "epoch", y = "train_loss", data = training_metrics)
# Out:
# <Axes: xlabel='epoch', ylabel='train_loss'>

# %%
sns.lineplot(x = "epoch", y = "val_multi_label_f1", data = training_metrics)
# Out:
# <Axes: xlabel='epoch', ylabel='val_multi_label_f1'>

# %%
filename = "/rds/general/user/ojf24/home/ml_project/vit_pretrained_fine_tune/tensorboard_logs/nih_cxr_pretrained_vit/version_7/checkpoint_evaluation/best_f1_scores_per_label.csv"
best_f1_per_label = pd.read_csv(filename)

# %%
best_f1_per_label
# Out:
#                  label  best_f1_score
# 0           No Finding       0.565305
# 1          Atelectasis       0.244867
# 2         Cardiomegaly       0.187031
# 3             Effusion       0.432175
# 4         Infiltration       0.396820
# 5                 Mass       0.265067
# 6               Nodule       0.148289
# 7            Pneumonia       0.042446
# 8         Pneumothorax       0.188599
# 9        Consolidation       0.132429
# 10               Edema       0.138874
# 11           Emphysema       0.165934
# 12            Fibrosis       0.033422
# 13  Pleural_Thickening       0.085493
# 14              Hernia       0.006697
