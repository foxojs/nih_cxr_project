# %%
import pandas as pd

# %%
filename_2_epochs = "/rds/general/user/ojf24/home/ml_project/vit_pretrained_fine_tune/tensorboard_logs/nih_cxr_pretrained_vit/version_8/test_multi_metrics_per_label_threshold.csv"

epoch_2 = pd.read_csv(filename_2_epochs)

filename_70_epochs = "/rds/general/user/ojf24/home/ml_project/vit_pretrained_fine_tune/tensorboard_logs/nih_cxr_pretrained_vit/version_7/checkpoint_evaluation/test_multi_metrics_per_label_threshold.csv"

epoch_70 = pd.read_csv(filename_70_epochs)

# %%
epoch_70
# Out:
#   Unnamed: 0   No Finding  Atelectasis  Cardiomegaly     Effusion  \
# 0  precision     0.450639     0.246073      0.345960     0.402069
# 1     recall     0.758240     0.243672      0.128157     0.467153
# 2   f1-score     0.565305     0.244867      0.187031     0.432175
# 3    support  9861.000000  3279.000000   1069.000000  4658.000000
#
#    Infiltration         Mass       Nodule   Pneumonia  Pneumothorax  \
# 0      0.329724     0.248252     0.132589    0.021683      0.104118
# 1      0.498200     0.284325     0.168207    1.000000      1.000000
# 2      0.396820     0.265067     0.148289    0.042446      0.188599
# 3   6112.000000  1748.000000  1623.000000  555.000000   2665.000000
#
#    Consolidation       Edema    Emphysema    Fibrosis  Pleural_Thickening  \
# 0       0.070910    0.135246     0.207703    0.016995            0.044655
# 1       1.000000    0.142703     0.138152    1.000000            1.000000
# ...

# %%
epoch_2
# Out:
#   Unnamed: 0   No Finding  Atelectasis  Cardiomegaly     Effusion  \
# 0  precision     0.512014     0.283910      0.450502     0.433245
# 1     recall     0.721732     0.520891      0.293732     0.599828
# 2   f1-score     0.599049     0.367509      0.355606     0.503106
# 3    support  9861.000000  3279.000000   1069.000000  4658.000000
#
#    Infiltration         Mass       Nodule   Pneumonia  Pneumothorax  \
# 0      0.317013     0.301065     0.232017    0.021683      0.358957
# 1      0.716132     0.355835     0.264325    1.000000      0.609756
# 2      0.439480     0.326167     0.247120    0.042446      0.451891
# 3   6112.000000  1748.000000  1623.000000  555.000000   2665.000000
#
#    Consolidation       Edema    Emphysema    Fibrosis  Pleural_Thickening  \
# 0       0.157570    0.215470     0.292603    0.155039            0.136712
# 1       0.435813    0.252973     0.488564    0.045977            0.280840
# ...
