# %%
import pandas as pd

# %%
filename = "/rds/general/user/ojf24/home/ml_project/vit_pretrained_fine_tune/tensorboard_logs/nih_cxr_pretrained_vit/version_5/metrics.csv"
training_metrics = pd.read_csv(filename)

# %%
training_metrics
# Out:
#       epoch    step  train_loss  val_multi_label_f1
# 0         0      49    0.262525                 NaN
# 1         0      99    0.179730                 NaN
# 2         0     149    0.159236                 NaN
# 3         0     199    0.092729                 NaN
# 4         0     249    0.149608                 NaN
# ...     ...     ...         ...                 ...
# 6472     37  321799    0.002605                 NaN
# 6473     37  321849    0.000328                 NaN
# 6474     37  321899    0.000077                 NaN
# 6475     37  321949    0.000738                 NaN
# 6476     37  321999    0.031061                 NaN
#
# [6477 rows x 4 columns]

# %%
import seaborn as sns

sns.lineplot(x = "epoch", y = "train_loss", data = training_metrics)
# Out:
# <Axes: xlabel='epoch', ylabel='train_loss'>

# %%
sns.lineplot(x = "epoch", y = "val_multi_label_f1", data = training_metrics)
# Out:
# <Axes: xlabel='epoch', ylabel='val_multi_label_f1'>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
labels = ["No Finding", "Atelectasis", "Cardiomegaly", "Effusion", "Infiltration",
          "Mass", "Nodule", "Pneumonia", "Pneumothorax", "Consolidation",
          "Edema", "Emphysema", "Fibrosis", "Pleural_Thickening", "Hernia"]

values = [0.565305, 0.244867, 0.187031, 0.432175, 0.396820,
          0.265067, 0.148289, 0.042446, 0.188599, 0.132429,
          0.138874, 0.165934, 0.033422, 0.085493, 0.006697]

# Number of variables
num_vars = len(labels)

# Compute angle for each axis in the plot (in radians)
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

# The plot is made by "closing" the circle, so we need to append the first value at the end
values += values[:1]
angles += angles[:1]

# Create the radar plot
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
ax.plot(angles, values, color='b', linewidth=2, linestyle='solid')
ax.fill(angles, values, color='b', alpha=0.25)

# Add labels to the axes
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels, fontsize=10)

# Add a title
ax.set_title("Radar Plot of Best F1 Scores", size=15, y=1.1)

plt.tight_layout()
plt.show()
